# %% [markdown]
# <a href="https://colab.research.google.com/github/JonMaycon/credit-risk-fraud/blob/main/03_DataPrep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Aplicação da preparação dos dados para algorítmos de Machine Learning.
#
# - Conceito de Metadados
#
# - Normalizações
#
# - Padronizações
#
# - Análise da Cardinalidade
#
# - OneHot Encoding
#
# - Label Encoding
#
# - Transformações de Variáveis

# %% [markdown]
# #### Leitura da ABT já desenvolvida na etapa anterior

# %%
#Mapear Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# Ler diretório Parquet
abt_00 = pd.read_parquet('/content/gdrive/MyDrive/PoD Academy/Ciências de Dados/Aulas_EndToEnd_ModeloCredito/1.Aula008/ABT', engine='pyarrow')
abt_00.shape
# Out:
# (1000, 26)

# %%
abt_00.head()
# Out:
#    Idade NM_GENERO  QT_DIAS_DESDE_INSCR  FL_USOU_SUPORTE          Plano  \
# 0     21         F                 1331                1  Intermediário
# 1     21         M                 1160                0  Intermediário
# 2     62         M                  454                1         Básico
# 3     64         M                  226                1  Intermediário
# 4     61         M                  474                1       Avançado
#
#    Churn  ID_CLIENTE  VL_TOT_CONSUMO  VL_MED_CONSUMO  VL_MAX_CONSUMO  ...  \
# 0      1           1         1976.56          116.27          199.39  ...
# 1      0           2         1017.80          101.78          192.63  ...
# 2      0           3          997.81          110.87          191.09  ...
# 3      0           4         1009.77          126.22          199.35  ...
# 4      0           5         1755.18          117.01          170.78  ...
#
#    VL_MED_CONS_Alimentos  VL_MED_U3M_CONS_Alimentos  \
# 0                  87.81                        NaN
# 1                  54.79                      47.58
# 2                 123.76                        NaN
# 3                 103.19                     103.19
# 4                 146.19                        NaN
#
#    VL_MED_U6M_CONS_Alimentos  VL_MED_U12M_CONS_Alimentos  \
# 0                     187.82                      187.82
# 1                      54.79                       54.79
# 2                        NaN                         NaN
# 3                     103.19                      103.19
# 4                        NaN                         NaN
#
#    VL_RAZ_MED_U3M_U6M_CONS_ESP  VL_RAZ_MED_U6M_U12M_CONS_ESP  \
# 0                          1.0                          1.00
# 1                          1.0                          0.68
# 2                          1.0                          1.00
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    VL_RAZ_MED_U3M_U6M_CONS_ALI  VL_RAZ_MED_U6M_U12M_CONS_ALI  PK_DAT_PROC  \
# 0                          NaN                           1.0   2026-01-30
# 1                         0.87                           1.0   2026-01-30
# 2                          NaN                           NaN   2026-01-30
# 3                         1.00                           1.0   2026-01-30
# 4                          NaN                           NaN   2026-01-30
#
#    PK_DATREF
# 0     202601
# 1     202601
# 2     202601
# 3     202601
# 4     202601
#
# [5 rows x 26 columns]

# %%
# Salvando arquivo como csv
abt_00.to_csv('abt_00_churn.csv')

# %% [markdown]
# ## Tratamento inicial
# - Separar uma parte dos dados (30%) para testes e validações
# - reservar lista de variaveis para retirar de tratamentos

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Dividindo o DataFrame em treino e teste
abt_01, abt_01_test = train_test_split(abt_00, test_size=0.3, random_state=42)


abt_01.shape,abt_01_test.shape
# Out:
# ((700, 26), (300, 26))

# %%
# lista de vars para retirar dos tratamentos

lista_spec = ['ID_CLIENTE', 'PK_DAT_PROC','PK_DATREF','Churn']

abt_01 = abt_01.drop(axis=1,columns = lista_spec)
abt_01.shape
# Out:
# (700, 22)

# %%
abt_01.head()
# Out:
#      Idade NM_GENERO  QT_DIAS_DESDE_INSCR  FL_USOU_SUPORTE          Plano  \
# 541     67         F                  997                0  Intermediário
# 440     55         F                 1777                1  Intermediário
# 482     62         F                 1721                1         Básico
# 422     63         M                 1690                0  Intermediário
# 778     40         F                  467                0       Avançado
#
#      VL_TOT_CONSUMO  VL_MED_CONSUMO  VL_MAX_CONSUMO  VL_MIN_CONSUMO  \
# 541          304.84          152.42          158.61          146.23
# 440          998.90           83.24          190.55           11.54
# 482         1508.11           79.37          176.20           15.87
# 422          430.84          107.71          143.14           61.42
# 778          364.08           91.02          189.14            9.01
#
#      VL_TOT_CONS_ESPORTES  ...  VL_MED_U6M_CONS_ESPORTES  \
# 541                  0.00  ...                       NaN
# 440                 17.01  ...                       NaN
# 482                463.59  ...                     35.86
# 422                  0.00  ...                       NaN
# 778                  0.00  ...                       NaN
#
#      VL_MED_U12M_CONS_ESPORTES  VL_MED_CONS_Alimentos  \
# 541                        NaN                    NaN
# 440                      17.01                 144.31
# 482                      35.86                  61.00
# 422                        NaN                    NaN
# 778                        NaN                    NaN
#
#      VL_MED_U3M_CONS_Alimentos  VL_MED_U6M_CONS_Alimentos  \
# 541                        NaN                        NaN
# 440                     190.55                     190.55
# 482                        NaN                        NaN
# 422                        NaN                        NaN
# 778                        NaN                        NaN
#
#      VL_MED_U12M_CONS_Alimentos  VL_RAZ_MED_U3M_U6M_CONS_ESP  \
# 541                         NaN                          NaN
# 440                      190.55                          NaN
# 482                         NaN                          1.0
# 422                         NaN                          NaN
# 778                         NaN                          NaN
#
#      VL_RAZ_MED_U6M_U12M_CONS_ESP  VL_RAZ_MED_U3M_U6M_CONS_ALI  \
# 541                           NaN                          NaN
# 440                           NaN                          1.0
# 482                           1.0                          NaN
# 422                           NaN                          NaN
# 778                           NaN                          NaN
#
#      VL_RAZ_MED_U6M_U12M_CONS_ALI
# 541                           NaN
# 440                           1.0
# 482                           NaN
# 422                           NaN
# 778                           NaN
#
# [5 rows x 22 columns]

# %%
abt_01.columns
# Out:
# Index(['Idade', 'NM_GENERO', 'QT_DIAS_DESDE_INSCR', 'FL_USOU_SUPORTE', 'Plano',
#        'VL_TOT_CONSUMO', 'VL_MED_CONSUMO', 'VL_MAX_CONSUMO', 'VL_MIN_CONSUMO',
#        'VL_TOT_CONS_ESPORTES', 'VL_MED_CONS_ESPORTES',
#        'VL_MED_U3M_CONS_ESPORTES', 'VL_MED_U6M_CONS_ESPORTES',
#        'VL_MED_U12M_CONS_ESPORTES', 'VL_MED_CONS_Alimentos',
#        'VL_MED_U3M_CONS_Alimentos', 'VL_MED_U6M_CONS_Alimentos',
#        'VL_MED_U12M_CONS_Alimentos', 'VL_RAZ_MED_U3M_U6M_CONS_ESP',
#        'VL_RAZ_MED_U6M_U12M_CONS_ESP', 'VL_RAZ_MED_U3M_U6M_CONS_ALI',
#        'VL_RAZ_MED_U6M_U12M_CONS_ALI'],
#       dtype='object')

# %% [markdown]
# ### Metadados

# %%
def pod_academy_generate_metadata(dataframe):
    """
    Gera um dataframe contendo metadados das colunas do dataframe fornecido.

    :param dataframe: DataFrame para o qual os metadados serão gerados.
    :return: DataFrame contendo metadados.
    """

    # Coleta de metadados básicos
    metadata = pd.DataFrame({
        'nome_variavel': dataframe.columns,
        'tipo': dataframe.dtypes,
        'qt_nulos': dataframe.isnull().sum(),
        'percent_nulos': round((dataframe.isnull().sum() / len(dataframe))* 100,2),
        'cardinalidade': dataframe.nunique(),
    })
    metadata=metadata.sort_values(by='percent_nulos',ascending=False)
    metadata = metadata.reset_index(drop=True)

    return metadata



# def pod_academy_generate_metadata(dataframe):
#     """
#     Gera um dataframe contendo metadados das colunas do dataframe fornecido, incluindo um teste de normalidade.

#     :param dataframe: DataFrame para o qual os metadados serão gerados.
#     :return: DataFrame contendo metadados.
#     """

#     # Coleta de metadados básicos
#     metadata = pd.DataFrame({
#         'nome_variavel': dataframe.columns,
#         'tipo': dataframe.dtypes,
#         'qt_nulos': dataframe.isnull().sum(),
#         'percent_nulos': round((dataframe.isnull().sum() / len(dataframe))* 100,2),
#         'cardinalidade': dataframe.nunique(),
#     })

#     # Função para testar normalidade usando o teste de Shapiro-Wilk
#     def test_normality(series, alpha=0.05):
#         if series.dtype in ["float64", "int64","int32"]:
#             statistic, p_value = stats.shapiro(series.dropna())  # dropping NA values for the test
#             return p_value > alpha
#         else:
#             return None  # Return None for non-numeric data types

#     # Aplicando teste de normalidade
#     metadata["fl_normal"] = dataframe.apply(test_normality)

#     metadata = metadata.sort_values(by='percent_nulos', ascending=False)
#     metadata = metadata.reset_index(drop=True)

#     return metadata

# %%
#### Vamos obter o metadados referente à nossa ABT
metadata_df = pod_academy_generate_metadata(abt_01)
metadata_df.head(100)
# Out:
#                    nome_variavel     tipo  qt_nulos  percent_nulos  \
# 0      VL_MED_U3M_CONS_Alimentos  float64       485          69.29
# 1    VL_RAZ_MED_U3M_U6M_CONS_ALI  float64       485          69.29
# 2    VL_RAZ_MED_U3M_U6M_CONS_ESP  float64       462          66.00
# 3       VL_MED_U3M_CONS_ESPORTES  float64       462          66.00
# 4   VL_RAZ_MED_U6M_U12M_CONS_ALI  float64       405          57.86
# 5      VL_MED_U6M_CONS_Alimentos  float64       405          57.86
# 6   VL_RAZ_MED_U6M_U12M_CONS_ESP  float64       396          56.57
# 7       VL_MED_U6M_CONS_ESPORTES  float64       396          56.57
# 8     VL_MED_U12M_CONS_Alimentos  float64       312          44.57
# 9      VL_MED_U12M_CONS_ESPORTES  float64       308          44.00
# 10         VL_MED_CONS_Alimentos  float64       148          21.14
# 11          VL_MED_CONS_ESPORTES  float64       136          19.43
# 12                     NM_GENERO   object         0           0.00
# 13                         Idade    int32         0           0.00
# 14                VL_TOT_CONSUMO  float64         0           0.00
# 15                         Plano   object         0           0.00
# 16               FL_USOU_SUPORTE    int32         0           0.00
# 17           QT_DIAS_DESDE_INSCR    int32         0           0.00
# 18                VL_MED_CONSUMO  float64         0           0.00
# 19                VL_MAX_CONSUMO  float64         0           0.00
# 20                VL_MIN_CONSUMO  float64         0           0.00
# 21          VL_TOT_CONS_ESPORTES  float64         0           0.00
#
#     cardinalidade
# 0             214
# 1              27
# 2              39
# 3             236
# 4              64
# 5             294
# 6              72
# 7             301
# 8             383
# 9             391
# 10            544
# 11            556
# 12              2
# 13             52
# 14            697
# 15              3
# 16              2
# 17            585
# 18            666
# 19            651
# 20            645
# 21            564

# %% [markdown]
# ## Tratamento dos valores nulos

# %%
import missingno as msno
# msno.matrix(abt_01, color=(0.25, 0.5, 1))  # tom de azul claro
msno.bar(abt_01, color=(0.25, 0.5, 1))  # tom de azul claro
# Out:
# <Axes: >

# %%
# Variáveis numéricas
# Filtrando o DataFrame
missing_cutoff = 70
df_numericas_drop_nulos = metadata_df[(metadata_df['percent_nulos'] >= missing_cutoff)]
lista_drop_nulos_numericas = list(df_numericas_drop_nulos.nome_variavel.values)
lista_drop_nulos_numericas
# Out:
# []

# %%
# retirando lista de variáveis com alto percentual de nulos
abt_02 = abt_01.drop(axis=1,columns=lista_drop_nulos_numericas)
abt_02.shape
# Out:
# (700, 22)

# %%
# substituindo nulos pela média da variável numérica
abt_02 = abt_02.fillna(abt_02.select_dtypes(include=['float64', 'int64','int32']).mean())
abt_02.shape
# Out:
# (700, 22)

# %%
abt_02.head()
# Out:
#      Idade NM_GENERO  QT_DIAS_DESDE_INSCR  FL_USOU_SUPORTE          Plano  \
# 541     67         F                  997                0  Intermediário
# 440     55         F                 1777                1  Intermediário
# 482     62         F                 1721                1         Básico
# 422     63         M                 1690                0  Intermediário
# 778     40         F                  467                0       Avançado
#
#      VL_TOT_CONSUMO  VL_MED_CONSUMO  VL_MAX_CONSUMO  VL_MIN_CONSUMO  \
# 541          304.84          152.42          158.61          146.23
# 440          998.90           83.24          190.55           11.54
# 482         1508.11           79.37          176.20           15.87
# 422          430.84          107.71          143.14           61.42
# 778          364.08           91.02          189.14            9.01
#
#      VL_TOT_CONS_ESPORTES  ...  VL_MED_U6M_CONS_ESPORTES  \
# 541                  0.00  ...                103.136382
# 440                 17.01  ...                103.136382
# 482                463.59  ...                 35.860000
# 422                  0.00  ...                103.136382
# 778                  0.00  ...                103.136382
#
#      VL_MED_U12M_CONS_ESPORTES  VL_MED_CONS_Alimentos  \
# 541                 101.116301             104.215127
# 440                  17.010000             144.310000
# 482                  35.860000              61.000000
# 422                 101.116301             104.215127
# 778                 101.116301             104.215127
#
#      VL_MED_U3M_CONS_Alimentos  VL_MED_U6M_CONS_Alimentos  \
# 541                 105.673395                 104.191525
# 440                 190.550000                 190.550000
# 482                 105.673395                 104.191525
# 422                 105.673395                 104.191525
# 778                 105.673395                 104.191525
#
#      VL_MED_U12M_CONS_Alimentos  VL_RAZ_MED_U3M_U6M_CONS_ESP  \
# 541                  104.449974                     1.005672
# 440                  190.550000                     1.005672
# 482                  104.449974                     1.000000
# 422                  104.449974                     1.005672
# 778                  104.449974                     1.005672
#
#      VL_RAZ_MED_U6M_U12M_CONS_ESP  VL_RAZ_MED_U3M_U6M_CONS_ALI  \
# 541                      1.001086                     0.998279
# 440                      1.001086                     1.000000
# 482                      1.000000                     0.998279
# 422                      1.001086                     0.998279
# 778                      1.001086                     0.998279
#
#      VL_RAZ_MED_U6M_U12M_CONS_ALI
# 541                      1.000915
# 440                      1.000000
# 482                      1.000915
# 422                      1.000915
# 778                      1.000915
#
# [5 rows x 22 columns]

# %%
# substituindo nulos por "Desconhecido" para categóricas
categorical_cols = abt_02.select_dtypes(include=['object']).columns
abt_02[categorical_cols] = abt_02[categorical_cols].fillna('Desconhecido')
abt_02.shape
# Out:
# (700, 22)

# %%
abt_02.head()
# Out:
#      Idade NM_GENERO  QT_DIAS_DESDE_INSCR  FL_USOU_SUPORTE          Plano  \
# 541     67         F                  997                0  Intermediário
# 440     55         F                 1777                1  Intermediário
# 482     62         F                 1721                1         Básico
# 422     63         M                 1690                0  Intermediário
# 778     40         F                  467                0       Avançado
#
#      VL_TOT_CONSUMO  VL_MED_CONSUMO  VL_MAX_CONSUMO  VL_MIN_CONSUMO  \
# 541          304.84          152.42          158.61          146.23
# 440          998.90           83.24          190.55           11.54
# 482         1508.11           79.37          176.20           15.87
# 422          430.84          107.71          143.14           61.42
# 778          364.08           91.02          189.14            9.01
#
#      VL_TOT_CONS_ESPORTES  ...  VL_MED_U6M_CONS_ESPORTES  \
# 541                  0.00  ...                103.136382
# 440                 17.01  ...                103.136382
# 482                463.59  ...                 35.860000
# 422                  0.00  ...                103.136382
# 778                  0.00  ...                103.136382
#
#      VL_MED_U12M_CONS_ESPORTES  VL_MED_CONS_Alimentos  \
# 541                 101.116301             104.215127
# 440                  17.010000             144.310000
# 482                  35.860000              61.000000
# 422                 101.116301             104.215127
# 778                 101.116301             104.215127
#
#      VL_MED_U3M_CONS_Alimentos  VL_MED_U6M_CONS_Alimentos  \
# 541                 105.673395                 104.191525
# 440                 190.550000                 190.550000
# 482                 105.673395                 104.191525
# 422                 105.673395                 104.191525
# 778                 105.673395                 104.191525
#
#      VL_MED_U12M_CONS_Alimentos  VL_RAZ_MED_U3M_U6M_CONS_ESP  \
# 541                  104.449974                     1.005672
# 440                  190.550000                     1.005672
# 482                  104.449974                     1.000000
# 422                  104.449974                     1.005672
# 778                  104.449974                     1.005672
#
#      VL_RAZ_MED_U6M_U12M_CONS_ESP  VL_RAZ_MED_U3M_U6M_CONS_ALI  \
# 541                      1.001086                     0.998279
# 440                      1.001086                     1.000000
# 482                      1.000000                     0.998279
# 422                      1.001086                     0.998279
# 778                      1.001086                     0.998279
#
#      VL_RAZ_MED_U6M_U12M_CONS_ALI
# 541                      1.000915
# 440                      1.000000
# 482                      1.000915
# 422                      1.000915
# 778                      1.000915
#
# [5 rows x 22 columns]

# %%
msno.bar(abt_02, color=(0.25, 0.5, 1))  # tom de azul claro
# Out:
# <Axes: >

# %%
# copiando dataframes para exemplos ludicos utilizando diferentes normalizações nos dados
abt_03 = abt_02.copy()
abt_04 = abt_02.copy()
abt_05 = abt_02.copy()

# %% [markdown]
# ## Tratamento das Variáveis Numéricas - Normalização
#
# A normalização é uma técnica usada para reescalar valores de uma variável para que eles fiquem dentro de um intervalo específico, geralmente entre 0 e 1. A equação para normalização é:
#
# $
# X_{\text{norm}} = \frac{X - X_{\text{min}}}{X_{\text{max}} - X_{\text{min}}}
# $
#
# Onde:
#
# - $ X $ é o valor atual que você deseja normalizar.
# - $ X_{\text{min}} $ é o valor mínimo da característica no conjunto de dados.
# - $ X_{\text{max}} $ é o valor máximo da característica no conjunto de dados.
# - $ X_{\text{norm}} $ é o valor normalizado de $ X $.
#
# Quando você aplica essa fórmula, garante que $ X_{\text{norm}} $ estará no intervalo [0,1]. Se você quiser normalizar em um intervalo diferente, como [a,b], pode ajustar a fórmula conforme necessário.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Definindo uma semente para reprodutibilidade
np.random.seed(42)

# Gerando dados com distribuição aproximadamente normal
# com média 5 e desvio padrão 2
data = 5 + 2 * np.random.randn(1000)

# Padronizando os dados
scaler = StandardScaler()
data_standardized = scaler.fit_transform(data.reshape(-1, 1)).flatten()

# Visualizando as distribuições
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Original data
ax[0].hist(data, bins=30, color='blue', alpha=0.7)
ax[0].set_title("Dado Original")
ax[0].set_xlabel("Valor")
ax[0].set_ylabel("Frequência")

# Standardized data
ax[1].hist(data_standardized, bins=30, color='green', alpha=0.7)
ax[1].set_title("Dado Padronizado")
ax[1].set_xlabel("Valor")
ax[1].set_ylabel("Frequência")

plt.tight_layout()
plt.show()

# %%
# Forma artesanal - implementando a formula na mão
numeric_cols = abt_02.select_dtypes(include=['float64', 'int64','int32']).columns
abt_02[numeric_cols] = abt_02[numeric_cols].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
abt_02.head()
# Out:
#         Idade NM_GENERO  QT_DIAS_DESDE_INSCR  FL_USOU_SUPORTE          Plano  \
# 541  0.960784         F             0.547253              0.0  Intermediário
# 440  0.725490         F             0.975824              1.0  Intermediário
# 482  0.862745         F             0.945055              1.0         Básico
# 422  0.882353         M             0.928022              0.0  Intermediário
# 778  0.431373         F             0.256044              0.0       Avançado
#
#      VL_TOT_CONSUMO  VL_MED_CONSUMO  VL_MAX_CONSUMO  VL_MIN_CONSUMO  \
# 541        0.112101        0.736069        0.761995        0.728723
# 440        0.393056        0.342307        0.945748        0.033548
# 482        0.599184        0.320280        0.863192        0.055897
# 422        0.163106        0.481587        0.672995        0.290994
# 778        0.136081        0.386590        0.937637        0.020490
#
#      VL_TOT_CONS_ESPORTES  ...  VL_MED_U6M_CONS_ESPORTES  \
# 541              0.000000  ...                  0.506475
# 440              0.016190  ...                  0.506475
# 482              0.441229  ...                  0.158379
# 422              0.000000  ...                  0.506475
# 778              0.000000  ...                  0.506475
#
#      VL_MED_U12M_CONS_ESPORTES  VL_MED_CONS_Alimentos  \
# 541                   0.496023               0.507888
# 440                   0.060848               0.715268
# 482                   0.158379               0.284370
# 422                   0.496023               0.507888
# 778                   0.496023               0.507888
#
#      VL_MED_U3M_CONS_Alimentos  VL_MED_U6M_CONS_Alimentos  \
# 541                   0.512698                   0.504997
# 440                   0.953799                   0.953799
# 482                   0.512698                   0.504997
# 422                   0.512698                   0.504997
# 778                   0.512698                   0.504997
#
#      VL_MED_U12M_CONS_Alimentos  VL_RAZ_MED_U3M_U6M_CONS_ESP  \
# 541                    0.509298                     0.419268
# 440                    0.954076                     0.419268
# 482                    0.509298                     0.415584
# 422                    0.509298                     0.419268
# 778                    0.509298                     0.419268
#
#      VL_RAZ_MED_U6M_U12M_CONS_ESP  VL_RAZ_MED_U3M_U6M_CONS_ALI  \
# 541                      0.491668                     0.459772
# 440                      0.491668                     0.460993
# 482                      0.491018                     0.459772
# 422                      0.491668                     0.459772
# 778                      0.491668                     0.459772
#
#      VL_RAZ_MED_U6M_U12M_CONS_ALI
# 541                      0.442089
# 440                      0.441624
# 482                      0.442089
# 422                      0.442089
# 778                      0.442089
#
# [5 rows x 22 columns]

# %%
abt_03.head()
# Out:
#      Idade NM_GENERO  QT_DIAS_DESDE_INSCR  FL_USOU_SUPORTE          Plano  \
# 541     67         F                  997                0  Intermediário
# 440     55         F                 1777                1  Intermediário
# 482     62         F                 1721                1         Básico
# 422     63         M                 1690                0  Intermediário
# 778     40         F                  467                0       Avançado
#
#      VL_TOT_CONSUMO  VL_MED_CONSUMO  VL_MAX_CONSUMO  VL_MIN_CONSUMO  \
# 541          304.84          152.42          158.61          146.23
# 440          998.90           83.24          190.55           11.54
# 482         1508.11           79.37          176.20           15.87
# 422          430.84          107.71          143.14           61.42
# 778          364.08           91.02          189.14            9.01
#
#      VL_TOT_CONS_ESPORTES  ...  VL_MED_U6M_CONS_ESPORTES  \
# 541                  0.00  ...                103.136382
# 440                 17.01  ...                103.136382
# 482                463.59  ...                 35.860000
# 422                  0.00  ...                103.136382
# 778                  0.00  ...                103.136382
#
#      VL_MED_U12M_CONS_ESPORTES  VL_MED_CONS_Alimentos  \
# 541                 101.116301             104.215127
# 440                  17.010000             144.310000
# 482                  35.860000              61.000000
# 422                 101.116301             104.215127
# 778                 101.116301             104.215127
#
#      VL_MED_U3M_CONS_Alimentos  VL_MED_U6M_CONS_Alimentos  \
# 541                 105.673395                 104.191525
# 440                 190.550000                 190.550000
# 482                 105.673395                 104.191525
# 422                 105.673395                 104.191525
# 778                 105.673395                 104.191525
#
#      VL_MED_U12M_CONS_Alimentos  VL_RAZ_MED_U3M_U6M_CONS_ESP  \
# 541                  104.449974                     1.005672
# 440                  190.550000                     1.005672
# 482                  104.449974                     1.000000
# 422                  104.449974                     1.005672
# 778                  104.449974                     1.005672
#
#      VL_RAZ_MED_U6M_U12M_CONS_ESP  VL_RAZ_MED_U3M_U6M_CONS_ALI  \
# 541                      1.001086                     0.998279
# 440                      1.001086                     1.000000
# 482                      1.000000                     0.998279
# 422                      1.001086                     0.998279
# 778                      1.001086                     0.998279
#
#      VL_RAZ_MED_U6M_U12M_CONS_ALI
# 541                      1.000915
# 440                      1.000000
# 482                      1.000915
# 422                      1.000915
# 778                      1.000915
#
# [5 rows x 22 columns]

# %%
# utilizando sklearn (recomendado - não reinventar a roda)

import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Instanciando o scaler
scaler = MinMaxScaler()

# Selecionando colunas numéricas
numeric_cols = abt_03.select_dtypes(include=['float64', 'int64','int32']).columns

# Aplicando a normalização
abt_03[numeric_cols] = scaler.fit_transform(abt_03[numeric_cols])
abt_03.shape
# Out:
# (700, 22)

# %%
abt_03.head()
# Out:
#         Idade NM_GENERO  QT_DIAS_DESDE_INSCR  FL_USOU_SUPORTE          Plano  \
# 541  0.960784         F             0.547253              0.0  Intermediário
# 440  0.725490         F             0.975824              1.0  Intermediário
# 482  0.862745         F             0.945055              1.0         Básico
# 422  0.882353         M             0.928022              0.0  Intermediário
# 778  0.431373         F             0.256044              0.0       Avançado
#
#      VL_TOT_CONSUMO  VL_MED_CONSUMO  VL_MAX_CONSUMO  VL_MIN_CONSUMO  \
# 541        0.112101        0.736069        0.761995        0.728723
# 440        0.393056        0.342307        0.945748        0.033548
# 482        0.599184        0.320280        0.863192        0.055897
# 422        0.163106        0.481587        0.672995        0.290994
# 778        0.136081        0.386590        0.937637        0.020490
#
#      VL_TOT_CONS_ESPORTES  ...  VL_MED_U6M_CONS_ESPORTES  \
# 541              0.000000  ...                  0.506475
# 440              0.016190  ...                  0.506475
# 482              0.441229  ...                  0.158379
# 422              0.000000  ...                  0.506475
# 778              0.000000  ...                  0.506475
#
#      VL_MED_U12M_CONS_ESPORTES  VL_MED_CONS_Alimentos  \
# 541                   0.496023               0.507888
# 440                   0.060848               0.715268
# 482                   0.158379               0.284370
# 422                   0.496023               0.507888
# 778                   0.496023               0.507888
#
#      VL_MED_U3M_CONS_Alimentos  VL_MED_U6M_CONS_Alimentos  \
# 541                   0.512698                   0.504997
# 440                   0.953799                   0.953799
# 482                   0.512698                   0.504997
# 422                   0.512698                   0.504997
# 778                   0.512698                   0.504997
#
#      VL_MED_U12M_CONS_Alimentos  VL_RAZ_MED_U3M_U6M_CONS_ESP  \
# 541                    0.509298                     0.419268
# 440                    0.954076                     0.419268
# 482                    0.509298                     0.415584
# 422                    0.509298                     0.419268
# 778                    0.509298                     0.419268
#
#      VL_RAZ_MED_U6M_U12M_CONS_ESP  VL_RAZ_MED_U3M_U6M_CONS_ALI  \
# 541                      0.491668                     0.459772
# 440                      0.491668                     0.460993
# 482                      0.491018                     0.459772
# 422                      0.491668                     0.459772
# 778                      0.491668                     0.459772
#
#      VL_RAZ_MED_U6M_U12M_CONS_ALI
# 541                      0.442089
# 440                      0.441624
# 482                      0.442089
# 422                      0.442089
# 778                      0.442089
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Padronização
#
# A padronização, também conhecida como z-score normalization, é um processo de reescalação que transforma as variáveis para ter média $ \mu = 0 $ e desvio padrão $ \sigma = 1 $.
#
# A equação para a padronização é:
#
# $
# Z = \frac{X - \mu}{\sigma}
# $
#
# Onde:
# - $ Z $ é o valor padronizado.
# - $ X $ é o valor original.
# - $ \mu $ é a média da característica.
# - $ \sigma $ é o desvio padrão da característica.

# %%
abt_04.head()
# Out:
#      Idade NM_GENERO  QT_DIAS_DESDE_INSCR  FL_USOU_SUPORTE          Plano  \
# 541     67         F                  997                0  Intermediário
# 440     55         F                 1777                1  Intermediário
# 482     62         F                 1721                1         Básico
# 422     63         M                 1690                0  Intermediário
# 778     40         F                  467                0       Avançado
#
#      VL_TOT_CONSUMO  VL_MED_CONSUMO  VL_MAX_CONSUMO  VL_MIN_CONSUMO  \
# 541          304.84          152.42          158.61          146.23
# 440          998.90           83.24          190.55           11.54
# 482         1508.11           79.37          176.20           15.87
# 422          430.84          107.71          143.14           61.42
# 778          364.08           91.02          189.14            9.01
#
#      VL_TOT_CONS_ESPORTES  ...  VL_MED_U6M_CONS_ESPORTES  \
# 541                  0.00  ...                103.136382
# 440                 17.01  ...                103.136382
# 482                463.59  ...                 35.860000
# 422                  0.00  ...                103.136382
# 778                  0.00  ...                103.136382
#
#      VL_MED_U12M_CONS_ESPORTES  VL_MED_CONS_Alimentos  \
# 541                 101.116301             104.215127
# 440                  17.010000             144.310000
# 482                  35.860000              61.000000
# 422                 101.116301             104.215127
# 778                 101.116301             104.215127
#
#      VL_MED_U3M_CONS_Alimentos  VL_MED_U6M_CONS_Alimentos  \
# 541                 105.673395                 104.191525
# 440                 190.550000                 190.550000
# 482                 105.673395                 104.191525
# 422                 105.673395                 104.191525
# 778                 105.673395                 104.191525
#
#      VL_MED_U12M_CONS_Alimentos  VL_RAZ_MED_U3M_U6M_CONS_ESP  \
# 541                  104.449974                     1.005672
# 440                  190.550000                     1.005672
# 482                  104.449974                     1.000000
# 422                  104.449974                     1.005672
# 778                  104.449974                     1.005672
#
#      VL_RAZ_MED_U6M_U12M_CONS_ESP  VL_RAZ_MED_U3M_U6M_CONS_ALI  \
# 541                      1.001086                     0.998279
# 440                      1.001086                     1.000000
# 482                      1.000000                     0.998279
# 422                      1.001086                     0.998279
# 778                      1.001086                     0.998279
#
#      VL_RAZ_MED_U6M_U12M_CONS_ALI
# 541                      1.000915
# 440                      1.000000
# 482                      1.000915
# 422                      1.000915
# 778                      1.000915
#
# [5 rows x 22 columns]

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Instanciando o scaler
scaler = StandardScaler()

# Ajustando e transformando os dados

# Selecionando colunas numéricas
numeric_cols = abt_04.select_dtypes(include=['float64', 'int64','int32']).columns

# Aplicando a normalização
abt_04[numeric_cols] = scaler.fit_transform(abt_04[numeric_cols])
abt_04.shape
# Out:
# (700, 22)

# %%
abt_04.head()
# Out:
#         Idade NM_GENERO  QT_DIAS_DESDE_INSCR  FL_USOU_SUPORTE          Plano  \
# 541  1.583371         F             0.135225        -1.049811  Intermediário
# 440  0.785320         F             1.646397         0.952553  Intermediário
# 482  1.250849         F             1.537903         0.952553         Básico
# 422  1.317354         M             1.477843        -1.049811  Intermediário
# 778 -0.212243         F            -0.891597        -1.049811       Avançado
#
#      VL_TOT_CONSUMO  VL_MED_CONSUMO  VL_MAX_CONSUMO  VL_MIN_CONSUMO  \
# 541       -1.245930        2.150143       -0.548968        3.586516
# 440       -0.060821       -0.875874        0.515401       -0.627463
# 482        0.808657       -1.045152        0.037201       -0.491992
# 422       -1.030785        0.194473       -1.064490        0.933108
# 778       -1.144778       -0.535567        0.468414       -0.706618
#
#      VL_TOT_CONS_ESPORTES  ...  VL_MED_U6M_CONS_ESPORTES  \
# 541             -1.122017  ...             -8.394527e-16
# 440             -1.032620  ...             -8.394527e-16
# 482              1.314406  ...             -1.987049e+00
# 422             -1.122017  ...             -8.394527e-16
# 778             -1.122017  ...             -8.394527e-16
#
#      VL_MED_U12M_CONS_ESPORTES  VL_MED_CONS_Alimentos  \
# 541                   0.000000           3.859226e-16
# 440                  -2.252893           1.088852e+00
# 482                  -1.747972          -1.173588e+00
# 422                   0.000000           3.859226e-16
# 778                   0.000000           3.859226e-16
#
#      VL_MED_U3M_CONS_Alimentos  VL_MED_U6M_CONS_Alimentos  \
# 541                   0.000000               8.126389e-16
# 440                   2.793175               2.469178e+00
# 482                   0.000000               8.126389e-16
# 422                   0.000000               8.126389e-16
# 778                   0.000000               8.126389e-16
#
#      VL_MED_U12M_CONS_Alimentos  VL_RAZ_MED_U3M_U6M_CONS_ESP  \
# 541               -3.782467e-16                     0.000000
# 440                2.291702e+00                     0.000000
# 482               -3.782467e-16                    -0.058542
# 422               -3.782467e-16                     0.000000
# 778               -3.782467e-16                     0.000000
#
#      VL_RAZ_MED_U6M_U12M_CONS_ESP  VL_RAZ_MED_U3M_U6M_CONS_ALI  \
# 541                  1.653675e-15                     0.000000
# 440                  1.653675e-15                     0.024635
# 482                 -8.084448e-03                     0.000000
# 422                  1.653675e-15                     0.000000
# 778                  1.653675e-15                     0.000000
#
#      VL_RAZ_MED_U6M_U12M_CONS_ALI
# 541                      0.000000
# 440                     -0.005813
# 482                      0.000000
# 422                      0.000000
# 778                      0.000000
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Tratamento das variáveis categóricas - Dummys
#
# - Variáveis de baixa cardinalidade
# - cardinalidade <= 10 (este valor de corte pode ser ajustado)

# %%
abt_04 = abt_02.copy()

# %%
abt_04[['NM_GENERO','Plano']].head()
# Out:
#     NM_GENERO          Plano
# 541         F  Intermediário
# 440         F  Intermediário
# 482         F         Básico
# 422         M  Intermediário
# 778         F       Avançado

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html

card_cutoff = 2
df_categ_onehot = metadata_df[(metadata_df['cardinalidade'] <= card_cutoff) & (metadata_df['tipo'] == 'object')]
lista_onehot = list(df_categ_onehot.nome_variavel.values)
print('Lista de vars para OneHot Encoding: ',lista_onehot)

# Instanciando o encoder (quando 2, nesse caso Masculino e Feminino)
encoder = OneHotEncoder(drop='first', sparse_output=False)

# Aplicando o one-hot encoding
encoded_data = encoder.fit_transform(abt_04[lista_onehot])

# Criando um DataFrame com as colunas codificadas, mantendo o índice original
encoded_cols = encoder.get_feature_names_out(lista_onehot)
encoded_df = pd.DataFrame(encoded_data, columns=encoded_cols, index=abt_04.index)

# Concatenando o DataFrame codificado com o DataFrame original
abt_04 = pd.concat([abt_04.drop(lista_onehot, axis=1), encoded_df], axis=1)

abt_04.head()
# Out:
# Lista de vars para OneHot Encoding:  ['NM_GENERO']
#         Idade  QT_DIAS_DESDE_INSCR  FL_USOU_SUPORTE          Plano  \
# 541  0.960784             0.547253              0.0  Intermediário
# 440  0.725490             0.975824              1.0  Intermediário
# 482  0.862745             0.945055              1.0         Básico
# 422  0.882353             0.928022              0.0  Intermediário
# 778  0.431373             0.256044              0.0       Avançado
#
#      VL_TOT_CONSUMO  VL_MED_CONSUMO  VL_MAX_CONSUMO  VL_MIN_CONSUMO  \
# 541        0.112101        0.736069        0.761995        0.728723
# 440        0.393056        0.342307        0.945748        0.033548
# 482        0.599184        0.320280        0.863192        0.055897
# 422        0.163106        0.481587        0.672995        0.290994
# 778        0.136081        0.386590        0.937637        0.020490
#
#      VL_TOT_CONS_ESPORTES  VL_MED_CONS_ESPORTES  ...  \
# 541              0.000000              0.497434  ...
# 440              0.016190              0.061085  ...
# 482              0.441229              0.373297  ...
# 422              0.000000              0.497434  ...
# 778              0.000000              0.497434  ...
#
#      VL_MED_U12M_CONS_ESPORTES  VL_MED_CONS_Alimentos  \
# 541                   0.496023               0.507888
# 440                   0.060848               0.715268
# 482                   0.158379               0.284370
# 422                   0.496023               0.507888
# 778                   0.496023               0.507888
#
#      VL_MED_U3M_CONS_Alimentos  VL_MED_U6M_CONS_Alimentos  \
# 541                   0.512698                   0.504997
# 440                   0.953799                   0.953799
# 482                   0.512698                   0.504997
# 422                   0.512698                   0.504997
# 778                   0.512698                   0.504997
#
#      VL_MED_U12M_CONS_Alimentos  VL_RAZ_MED_U3M_U6M_CONS_ESP  \
# 541                    0.509298                     0.419268
# 440                    0.954076                     0.419268
# 482                    0.509298                     0.415584
# 422                    0.509298                     0.419268
# 778                    0.509298                     0.419268
#
#      VL_RAZ_MED_U6M_U12M_CONS_ESP  VL_RAZ_MED_U3M_U6M_CONS_ALI  \
# 541                      0.491668                     0.459772
# 440                      0.491668                     0.460993
# 482                      0.491018                     0.459772
# 422                      0.491668                     0.459772
# 778                      0.491668                     0.459772
#
#      VL_RAZ_MED_U6M_U12M_CONS_ALI  NM_GENERO_M
# 541                      0.442089          0.0
# 440                      0.441624          0.0
# 482                      0.442089          0.0
# 422                      0.442089          1.0
# 778                      0.442089          0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Tratamento das variáveis categóricas de alta cardinalidade

# %%
card_cutoff = 2
df_categ_labelenc = metadata_df[(metadata_df['cardinalidade'] > card_cutoff) & (metadata_df['tipo'] == 'object')]
lista_lenc = list(df_categ_labelenc.nome_variavel.values)
print('Lista de vars para Label Encoding: ',lista_lenc)
# Out:
# Lista de vars para Label Encoding:  ['Plano']

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Aplicando LabelEncoder nas colunas desejadas
for col in lista_lenc:
    encoder = LabelEncoder()
    abt_04[col] = encoder.fit_transform(abt_04[col])

abt_04.head()
# Out:
#         Idade  QT_DIAS_DESDE_INSCR  FL_USOU_SUPORTE  Plano  VL_TOT_CONSUMO  \
# 541  0.960784             0.547253              0.0      2        0.112101
# 440  0.725490             0.975824              1.0      2        0.393056
# 482  0.862745             0.945055              1.0      1        0.599184
# 422  0.882353             0.928022              0.0      2        0.163106
# 778  0.431373             0.256044              0.0      0        0.136081
#
#      VL_MED_CONSUMO  VL_MAX_CONSUMO  VL_MIN_CONSUMO  VL_TOT_CONS_ESPORTES  \
# 541        0.736069        0.761995        0.728723              0.000000
# 440        0.342307        0.945748        0.033548              0.016190
# 482        0.320280        0.863192        0.055897              0.441229
# 422        0.481587        0.672995        0.290994              0.000000
# 778        0.386590        0.937637        0.020490              0.000000
#
#      VL_MED_CONS_ESPORTES  ...  VL_MED_U12M_CONS_ESPORTES  \
# 541              0.497434  ...                   0.496023
# 440              0.061085  ...                   0.060848
# 482              0.373297  ...                   0.158379
# 422              0.497434  ...                   0.496023
# 778              0.497434  ...                   0.496023
#
#      VL_MED_CONS_Alimentos  VL_MED_U3M_CONS_Alimentos  \
# 541               0.507888                   0.512698
# 440               0.715268                   0.953799
# 482               0.284370                   0.512698
# 422               0.507888                   0.512698
# 778               0.507888                   0.512698
#
#      VL_MED_U6M_CONS_Alimentos  VL_MED_U12M_CONS_Alimentos  \
# 541                   0.504997                    0.509298
# 440                   0.953799                    0.954076
# 482                   0.504997                    0.509298
# 422                   0.504997                    0.509298
# 778                   0.504997                    0.509298
#
#      VL_RAZ_MED_U3M_U6M_CONS_ESP  VL_RAZ_MED_U6M_U12M_CONS_ESP  \
# 541                     0.419268                      0.491668
# 440                     0.419268                      0.491668
# 482                     0.415584                      0.491018
# 422                     0.419268                      0.491668
# 778                     0.419268                      0.491668
#
#      VL_RAZ_MED_U3M_U6M_CONS_ALI  VL_RAZ_MED_U6M_U12M_CONS_ALI  NM_GENERO_M
# 541                     0.459772                      0.442089          0.0
# 440                     0.460993                      0.441624          0.0
# 482                     0.459772                      0.442089          0.0
# 422                     0.459772                      0.442089          1.0
# 778                     0.459772                      0.442089          0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Compondo a ABT tratada
# - Trazendo Target

# %%
# Inner join usando o índice
abt_model = pd.merge(abt_04, abt_00[['Churn']], left_index=True, right_index=True, how='inner')
abt_model.shape
# Out:
# (700, 23)

# %%
abt_model.head()
# Out:
#         Idade  QT_DIAS_DESDE_INSCR  FL_USOU_SUPORTE  Plano  VL_TOT_CONSUMO  \
# 541  0.960784             0.547253              0.0      2        0.112101
# 440  0.725490             0.975824              1.0      2        0.393056
# 482  0.862745             0.945055              1.0      1        0.599184
# 422  0.882353             0.928022              0.0      2        0.163106
# 778  0.431373             0.256044              0.0      0        0.136081
#
#      VL_MED_CONSUMO  VL_MAX_CONSUMO  VL_MIN_CONSUMO  VL_TOT_CONS_ESPORTES  \
# 541        0.736069        0.761995        0.728723              0.000000
# 440        0.342307        0.945748        0.033548              0.016190
# 482        0.320280        0.863192        0.055897              0.441229
# 422        0.481587        0.672995        0.290994              0.000000
# 778        0.386590        0.937637        0.020490              0.000000
#
#      VL_MED_CONS_ESPORTES  ...  VL_MED_CONS_Alimentos  \
# 541              0.497434  ...               0.507888
# 440              0.061085  ...               0.715268
# 482              0.373297  ...               0.284370
# 422              0.497434  ...               0.507888
# 778              0.497434  ...               0.507888
#
#      VL_MED_U3M_CONS_Alimentos  VL_MED_U6M_CONS_Alimentos  \
# 541                   0.512698                   0.504997
# 440                   0.953799                   0.953799
# 482                   0.512698                   0.504997
# 422                   0.512698                   0.504997
# 778                   0.512698                   0.504997
#
#      VL_MED_U12M_CONS_Alimentos  VL_RAZ_MED_U3M_U6M_CONS_ESP  \
# 541                    0.509298                     0.419268
# 440                    0.954076                     0.419268
# 482                    0.509298                     0.415584
# 422                    0.509298                     0.419268
# 778                    0.509298                     0.419268
#
#      VL_RAZ_MED_U6M_U12M_CONS_ESP  VL_RAZ_MED_U3M_U6M_CONS_ALI  \
# 541                      0.491668                     0.459772
# 440                      0.491668                     0.460993
# 482                      0.491018                     0.459772
# 422                      0.491668                     0.459772
# 778                      0.491668                     0.459772
#
#      VL_RAZ_MED_U6M_U12M_CONS_ALI  NM_GENERO_M  Churn
# 541                      0.442089          0.0      0
# 440                      0.441624          0.0      0
# 482                      0.442089          0.0      0
# 422                      0.442089          1.0      1
# 778                      0.442089          0.0      1
#
# [5 rows x 23 columns]
